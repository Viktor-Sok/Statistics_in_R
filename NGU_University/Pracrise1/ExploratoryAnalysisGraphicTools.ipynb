# %%
data <- read.csv("DescriptiveStatistics.csv", dec = ".", sep =";")

# %%
summary(data)
# Out:
#     Distance           Class
#  Min.   :  693.2   Min.   :0.00000
#  1st Qu.: 3747.4   1st Qu.:0.00000
#  Median : 5439.3   Median :0.00000
#  Mean   : 6143.5   Mean   :0.04035
#  3rd Qu.: 7932.0   3rd Qu.:0.00000
#  Max.   :19293.8   Max.   :1.00000

# %%
head(data)
# Distance from customer to nearest store
# Class means importance of the distance for customer
# Out:
#   Distance  Class
# 1  693.1873 0
# 2  695.4761 1
# 3  808.7228 1
# 4  862.7375 1
# 5  894.0739 1
# 6 1074.1563 1

# %%
str(data)
# Out:
# 'data.frame':	694 obs. of  2 variables:
#  $ Distance: num  693 695 809 863 894 ...
#  $ Class   : int  0 1 1 1 1 1 0 1 1 1 ...

# %%
#hist(data$Distance, las = 1,cex = 1)
#lines(density(data$Distance))
lines(density(data$Distance))
# Out:
# Plot with title “density.default(x = data$Distance)”

# %%
mean(data$Distance)
# Out:
# [1] 6143.468

# %%
median(data$Distance)
# Out:
# [1] 5439.326

# %%
quantile(data$Distance)
# Out:
#         0%        25%        50%        75%       100%
#   693.1873  3747.4136  5439.3261  7931.9621 19293.8276

# %%
summary(data$Distance)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   693.2  3747.4  5439.3  6143.5  7932.0 19293.8

# %%
var(data$Distance)
# Out:
# [1] 11133685

# %%
sqrt(var(data$Distance))
# Out:
# [1] 3336.718

# %%
sd(data$Distance)
# Out:
# [1] 3336.718

# %% [markdown]
# # Graphical Representation

# %%
#emperical umulative distribution function
plot(ecdf(data$Distance), cex = 0.5, las =1)
# Out:
# Plot with title “ecdf(data$Distance)”

# %%
#histogram
hist(data$Distance)
# Out:
# Plot with title “Histogram of data$Distance”

# %%
hist(data$Distance,"Freedman-Diaconis")
# Out:
# Plot with title “Histogram of data$Distance”

# %%
#boxplot
boxplot(data$Distance)
# Out:
# plot without title

# %%
#dividing data in different classes
class0 <- data$Distance[which(data$Class == 0 )]
class1 <- data$Distance[which(data$Class == 1 )]
#class0 <- data[data$Class == 0, ]

# %%
boxplot(class0, class1, varwidth = TRUE)
# Out:
# plot without title
